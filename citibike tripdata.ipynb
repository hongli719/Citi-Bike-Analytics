# %%
import csv
import pandas as pd

# %%
df1 = pd.read_csv("data/JC-201809-citibike-tripdata.csv")
df2 = pd.read_csv("data/JC-201810-citibike-tripdata.csv")
df3 = pd.read_csv("data/JC-201811-citibike-tripdata.csv")

# %%
df1.head()
df1.count
# Out:
# <bound method DataFrame.count of        tripduration                 starttime                  stoptime  \
# 0               284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1               370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2              1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3               383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4               377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
# 5               497  2018-09-01 10:23:15.7840  2018-09-01 10:31:32.9800
# 6               426  2018-09-01 10:49:48.2870  2018-09-01 10:56:54.3760
# 7               138  2018-09-01 11:01:00.9880  2018-09-01 11:03:19.2540
# 8               280  2018-09-01 11:41:15.9230  2018-09-01 11:45:56.1620
# 9              2026  2018-09-01 11:43:57.4740  2018-09-01 12:17:44.1050
# 10             2020  2018-09-01 11:44:12.4460  2018-09-01 12:17:52.9200
# 11             2088  2018-09-01 11:51:51.0010  2018-09-01 12:26:39.2900
# ...

# %%
df2.head()
df2.count
# Out:
# <bound method DataFrame.count of        tripduration                 starttime                  stoptime  \
# 0               152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1               122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2               211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3               342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4              2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
# 5              2973  2018-10-01 10:45:17.5980  2018-10-01 11:34:50.9450
# 6              1295  2018-10-01 11:51:25.1460  2018-10-01 12:13:00.9240
# 7               262  2018-10-01 12:02:33.5180  2018-10-01 12:06:55.6080
# 8               277  2018-10-01 12:03:52.5690  2018-10-01 12:08:30.0080
# 9               706  2018-10-01 12:33:40.6430  2018-10-01 12:45:26.9410
# 10              262  2018-10-01 13:15:24.3220  2018-10-01 13:19:46.6460
# 11             1298  2018-10-01 13:19:31.1410  2018-10-01 13:41:09.9350
# ...

# %%
df3.head()
df3.count
# Out:
# <bound method DataFrame.count of        tripduration                 starttime                  stoptime  \
# 0              1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 1               278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 2               115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 3               155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 4                82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
# 5               310  2018-11-01 08:53:23.7250  2018-11-01 08:58:33.7260
# 6               203  2018-11-01 08:54:47.4150  2018-11-01 08:58:10.7250
# 7               176  2018-11-01 09:04:07.4190  2018-11-01 09:07:03.4640
# 8               269  2018-11-01 09:52:26.7690  2018-11-01 09:56:56.0670
# 9              1010  2018-11-01 11:11:43.7110  2018-11-01 11:28:33.7280
# 10             1001  2018-11-01 11:11:51.8740  2018-11-01 11:28:33.1490
# 11              986  2018-11-01 11:12:04.6990  2018-11-01 11:28:31.6030
# ...

# %%
df = df1.append(df2)

# %%
df = df.append(df3)

# %%
df.count
# Out:
# <bound method DataFrame.count of        tripduration                 starttime                  stoptime  \
# 0               284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1               370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2              1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3               383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4               377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
# 5               497  2018-09-01 10:23:15.7840  2018-09-01 10:31:32.9800
# 6               426  2018-09-01 10:49:48.2870  2018-09-01 10:56:54.3760
# 7               138  2018-09-01 11:01:00.9880  2018-09-01 11:03:19.2540
# 8               280  2018-09-01 11:41:15.9230  2018-09-01 11:45:56.1620
# 9              2026  2018-09-01 11:43:57.4740  2018-09-01 12:17:44.1050
# 10             2020  2018-09-01 11:44:12.4460  2018-09-01 12:17:52.9200
# 11             2088  2018-09-01 11:51:51.0010  2018-09-01 12:26:39.2900
# ...

# %%
df.to_csv("data/citibike-tripdata.csv", encoding="utf-8")
